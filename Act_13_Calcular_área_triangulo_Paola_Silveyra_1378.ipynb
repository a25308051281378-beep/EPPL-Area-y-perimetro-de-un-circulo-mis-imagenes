# %% [markdown]
# <a href="https://colab.research.google.com/github/a25308051281378-beep/EPPL-Area-y-perimetro-de-un-circulo-mis-imagenes/blob/main/Act_13_Calcular_%C3%A1rea_triangulo_Paola_Silveyra_1378.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![logo de Markdown](https://raw.githubusercontent.com/a25308051281378-beep/EPPL-Area-y-perimetro-de-un-circulo-mis-imagenes/refs/heads/main/formula-del-area-de-un-triangulo-rectangulo.webp)
#
# ## Formula para calcular Area
# $$A = \frac{b \cdot h}{2}$$
#
# # Datos de entrada
# *   b = ?
# *   h = ?
# ---
# ## Diagrama de flujo en LucidChart
# ![logo de Markdown](https://raw.githubusercontent.com/a25308051281378-beep/EPPL-Area-y-perimetro-de-un-circulo-mis-imagenes/refs/heads/main/DF%20Area%20y%20perimetro%20de%20un%20triangulo.png)
# ---

# %%
# Calcular el area de un triangulo
# Variables: b (base), h(altura), A(area)
# Formula: A = (base * altura) / 2
# Capturar los valores de b y h

print("Calcular el area de un triangulo")

b = int(input("Ingrese el valor de la base: "))
h = int(input("Ingrese el valor de la altura: "))

# Aplicamos la formula A = (b * h) / 2
A = (b * h) / 2

print("El area del triangulo es: ", A)
print("Programa realizado por Paola Silveyra NL = 50")
# Out:
# Calcular el area de un triangulo
# Ingrese el valor de la base: 4
# Ingrese el valor de la altura: 6
# El area del triangulo es:  12.0
# Programa realizado por Paola Silveyra NL = 50

# %% [markdown]
# ## Relacion entre codigo y DF en Tldraw
# ![logo de Markdown](https://raw.githubusercontent.com/a25308051281378-beep/EPPL-Area-y-perimetro-de-un-circulo-mis-imagenes/refs/heads/main/DF%20area%20del%20triangulo%20rectangulo.png)
