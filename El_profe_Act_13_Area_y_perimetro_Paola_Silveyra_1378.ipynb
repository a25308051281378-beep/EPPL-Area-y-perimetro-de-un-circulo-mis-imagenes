# %% [markdown]
# <a href="https://colab.research.google.com/github/a25308051281378-beep/EPPL-Area-y-perimetro-de-un-circulo-mis-imagenes/blob/main/El_profe_Act_13_Area_y_perimetro_Paola_Silveyra_1378.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Paola Silveyra NL = 50 Fecha 25/03/26 💓
# ---
# # Calculando Area y perimetro de un circulo
# ---
#
# ![Fórmulas para calcular la circunferencia](https://matematix.org/wp-content/uploads/cuales-son-las-formulas-para-calcular-la-circunferencia.jpg)
#
# ---
# ## Formula para calcular Area
# $A=\pi*r^2$
# ---
# ## Formula para calcular perimetro
# $P=2*\pi*r$
# ---
# ## Datos de entrada
# $r$ ?
# ---
# ## Diagrama de flujo en Lucidchart
# ![logo de markdown](https://raw.githubusercontent.com/a25308051281378-beep/EPPL-Area-y-perimetro-de-un-circulo-mis-imagenes/refs/heads/main/Area_perimetro_circulo.png)

# %%
# calcular area y perimetro de un circulo
# variables A,P r
# formulas A = pi*r^2 y P = 2 * PI * R
# capturar el valor de r
import math
print("Calcular area y perimetro de un circulo")
r = float(input("Ingrese el valor del radio: "))
A = math.pi*r**2
P = 2*math.pi*r
print("El area del circulo es: ",A)
print("El perimetro del circulo es: ",P)
print("Paola Silveyra NL = 50")
# Out:
# Calcular area y perimetro de un circulo
# Ingrese el valor del radio: 5
# El area del circulo es:  78.53981633974483
# El perimetro del circulo es:  31.41592653589793
# Paola Silveyra NL = 50

# %% [markdown]
# # Relacion entre codigos y DF en Tldraw
# ![logo de markdown](https://raw.githubusercontent.com/a25308051281378-beep/EPPL-Area-y-perimetro-de-un-circulo-mis-imagenes/refs/heads/main/DF%20Area%20y%20perimetro%20del%20circulo.png)
